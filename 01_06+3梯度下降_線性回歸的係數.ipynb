# %% [markdown]
# <a href="https://colab.research.google.com/github/bin010203/hello-world/blob/master/01_06%2B3%E6%A2%AF%E5%BA%A6%E4%B8%8B%E9%99%8D_%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8%E7%9A%84%E4%BF%82%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 實作06：利用梯度下降法求簡單線性回歸的係數

# %% [markdown]
# ### (0)掛載雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (1)import必要的套件

# %%
import numpy as np
from IPython import display
import matplotlib.pyplot as plt
import matplotlib.font_manager as plt_font
twfont1 = plt_font.FontProperties(fname="/content/drive/MyDrive/Colab Notebooks/kaiu.ttf")

# %%
import pandas as pd

# %% [markdown]
# ### (2)將原始資料分為訓練資料集和驗證資料集

# %%
#由SalesVolume.csv檔案載入資料集
data= np.loadtxt("/content/drive/MyDrive/Colab Notebooks/SalesVolume.csv",delimiter=",")

# %%
data
# Out:
# array([[ 24.,  22.,  15.,   4.,   9.,  20.,   5.,   3.,  17.,  19.,  13.,
#          10.,  12.,  11.,  16.,  27.,  16.,  16.,   6.,  20.],
#        [591., 543., 410., 310., 319., 520., 338., 330., 501., 508., 399.,
#         331., 390., 390., 431., 660., 409., 430., 323., 524.]])

# %%
df = pd.DataFrame(data)
df
# Out:
#       0      1      2      3      4   ...     15     16     17     18     19
# 0   24.0   22.0   15.0    4.0    9.0  ...   27.0   16.0   16.0    6.0   20.0
# 1  591.0  543.0  410.0  310.0  319.0  ...  660.0  409.0  430.0  323.0  524.0
#
# [2 rows x 20 columns]

# %%
#DataFrame隨機排序 frac=1傳回全部的項目,
#reset_index() 方法來重置 DataFrame 索引
#drop=True 選項防止將 index 新增為新的行(column)。
df_shuffled=df.sample(frac=1,axis=1).reset_index(drop=True)
df_shuffled
# Out:
#       19     12     3      7      4   ...     14     13     9      1      10
# 0   20.0   12.0    4.0    3.0    9.0  ...   16.0   11.0   19.0   22.0   13.0
# 1  524.0  390.0  310.0  330.0  319.0  ...  431.0  390.0  508.0  543.0  399.0
#
# [2 rows x 20 columns]

# %%
data = np.array(df_shuffled)

# %%
data
# Out:
# array([[ 20.,  12.,   4.,   3.,   9.,  27.,   6.,  16.,  17.,  24.,   5.,
#          16.,  15.,  10.,  20.,  16.,  11.,  19.,  22.,  13.],
#        [524., 390., 310., 330., 319., 660., 323., 409., 501., 591., 338.,
#         430., 410., 331., 520., 431., 390., 508., 543., 399.]])

# %%
data_x=data[0]#第1列為廣告推播次數
data_y=data[1]#第2列為商品銷售數量
#訓練資料集12筆
train_x=data_x[:12]
train_y=data_y[:12]
#驗證資料集8筆
valid_x=data_x[12:]
valid_y=data_y[12:]

# %%
data_x
# Out:
# array([20., 12.,  4.,  3.,  9., 27.,  6., 16., 17., 24.,  5., 16., 15.,
#        10., 20., 16., 11., 19., 22., 13.])

# %%
train_x
# Out:
# array([20., 12.,  4.,  3.,  9., 27.,  6., 16., 17., 24.,  5., 16.])

# %%
valid_x
# Out:
# array([15., 10., 20., 16., 11., 19., 22., 13.])

# %% [markdown]
# ### (3)隨機初始化偏值b，權重w

# %%
b=np.random.rand()
w=np.random.rand()
print("b = ",b ," w = ",w)
# Out:
# b =  0.3423928189820217  w =  0.9227732309862049

# %% [markdown]
# ## (4)定義迴歸模型的線性函數

# %% [markdown]
# ###偏值b，權重w(斜率)

# %%
def F(x):
  return b+w*x

# %% [markdown]
# ## (5)定義損失函數LOSS Funcation

# %%
# L=1/2*(y-y^)**2
def Loss(x,y):
  return 0.5*np.sum((y-F(x))**2)

# %% [markdown]
# ## (6)設定學習率和權重更新次數

# %%
ETA=0.0001#學習率
#儲存學習的狀態,# 偏值b，權重w(斜率)
Step_Loss=[]
Step_b=[]
Step_w=[]

# %% [markdown]
# ## (7)開始訓練模型,看Loss值變化化圖形,for 迴圈可以改成13000~15000

# %%
# epoch 訓練的回合, ETA 學習率
# 偏值b，權重w(斜率)
for epoch in range(20000):
  b=b-ETA*np.sum(F(train_x)-train_y)
  w=w-ETA*np.sum((F(train_x)-train_y)*train_x)
            #跑100次才印一次,epoch從0開始,故+1,印太多會降低效率
  if epoch%100==99:
    current_loss=Loss(train_x,train_y)
    print("訓練次數:",epoch+1,"\nb:",b,"\nw:",w,
          "\n損失函數:",current_loss)
    Step_Loss.append(current_loss)
    Step_b.append(b)
    Step_w.append(w)
    #display.clear_output(wait=True)
# Out:
# 訓練次數: 100
# b: 8.985936241021403
# w: 27.133038372146512
# 損失函數: 88302.04999122219
# 訓練次數: 200
# b: 15.912074575097623
# w: 26.741804946677206
# 損失函數: 83494.27347447973
# 訓練次數: 300
# b: 22.63223093919396
# w: 26.362206725099654
# 損失函數: 78968.20931803045
# 訓練次數: 400
# b: 29.152531195935484
# w: 25.993897678775312
# 損失函數: 74707.35054538208
# 訓練次數: 500
# b: 35.47891902601697
# w: 25.636542069888115
# 損失函數: 70696.15740871712
# 訓練次數: 600
# b: 41.61716134625701
# w: 25.28981414539755
# 損失函數: 66920.0007139888
# 訓練次數: 700
# b: 47.57285356652053
# w: 24.953397840093423
# 損失函數: 63365.10846689115
# 訓練次數: 800
# b: 53.35142469030118
# w: 24.626986488481737
# 損失函數: 60018.51564511629
# 訓練次數: 900
# b: 58.958142263613595
# w: 24.310282545239012
# 損失函數: 56868.01691371337
# 訓練次數: 1000
# b: 64.39811717670655
# w: 24.002997313980217
# 損失函數: 53902.12211109823
# 訓練次數: 1100
# b: 69.67630832297417
# w: 23.70485068409313
# 損失函數: 51110.01434336634
# 訓練次數: 1200
# b: 74.7975271193121
# w: 23.41557087539915
# 損失函數: 48481.51053407582
# 訓練次數: 1300
# b: 79.76644189203881
# w: 23.134894190407888
# 損失函數: 46007.02428562161
# 訓練次數: 1400
# b: 84.58758213238102
# w: 22.862564773939617
# 損失函數: 43677.5309167527
# 訓練次數: 1500
# b: 89.2653426254015
# w: 22.59833437989653
# 損失函數: 41484.534548721094
# 訓練次數: 1600
# b: 93.80398745613363
# w: 22.341962144970157
# 損失函數: 39420.037120022665
# 訓練次數: 1700
# b: 98.20765389657373
# w: 22.093214369078698
# 損失函數: 37476.50921672388
# 訓練次數: 1800
# b: 102.48035617707592
# w: 21.851864302334068
# 損失函數: 35646.86261198947
# 訓練次數: 1900
# b: 106.6259891455857
# w: 21.617691938344556
# 損失函數: 33924.42441466068
# 訓練次數: 2000
# b: 110.64833181804902
# w: 21.390483813664574
# 損失函數: 32302.912732601224
# 訓練次數: 2100
# b: 114.5510508232327
# w: 21.170032813208746
# 損失函數: 30776.41376205305
# 訓練次數: 2200
# b: 118.33770374509686
# w: 20.95613798145294
# 損失函數: 29339.360219444505
# 訓練次數: 2300
# b: 122.0117423657654
# w: 20.74860433925017
# 損失函數: 27986.511036990032
# 訓練次數: 2400
# b: 125.57651581205188
# w: 20.547242706094302
# 損失函數: 26712.93224802882
# 訓練次數: 2500
# b: 129.03527360840755
# w: 20.351869527669656
# 損失函數: 25513.97899239016
# 訓練次數: 2600
# b: 132.3911686390757
# w: 20.162306708529233
# 損失函數: 24385.2785761568
# 訓練次數: 2700
# b: 135.6472600221526
# w: 19.97838144974901
# 損失函數: 23322.714524043877
# 訓練次數: 2800
# b: 138.80651589817364
# w: 19.799926091410438
# 損失函數: 22322.41156623112
# 訓練次數: 2900
# b: 141.87181613576735
# w: 19.626777959767477
# 損失函數: 21380.72150489402
# 訓練次數: 3000
# b: 144.8459549568452
# w: 19.458779218958753
# 損失函數: 20494.209908887
# 訓練次數: 3100
# b: 147.7316434837171
# w: 19.295776727129887
# 損失函數: 19659.643588054252
# 訓練次數: 3200
# b: 150.53151221045752
# w: 19.137621896834624
# 損失函數: 18873.978801484638
# 訓練次數: 3300
# b: 153.24811340077275
# w: 18.98417055958768
# 損失函數: 18134.35015670591
# 訓練次數: 3400
# b: 155.88392341455642
# w: 18.83528283444572
# 損失函數: 17438.060159332144
# 訓練次數: 3500
# b: 158.44134496525365
# w: 18.690823000496703
# 損失函數: 16782.569375051113
# 訓練次數: 3600
# b: 160.92270931009205
# w: 18.550659373141393
# 損失函數: 16165.487168071279
# 訓練次數: 3700
# b: 163.33027837517514
# w: 18.41466418405422
# 損失函數: 15584.562982251067
# 訓練次數: 3800
# b: 165.66624681737602
# w: 18.282713464714075
# 損失函數: 15037.678133111522
# 訓練次數: 3900
# b: 167.9327440249109
# w: 18.154686933398917
# 損失函數: 14522.838080797119
# 訓練次數: 4000
# b: 170.13183605841607
# w: 18.030467885541068
# 損失函數: 14038.16515580363
# 訓練次數: 4100
# b: 172.26552753429735
# w: 17.909943087343365
# 損失函數: 13581.891710942931
# 訓練次數: 4200
# b: 174.33576345206947
# w: 17.79300267255914
# 損失函數: 13152.353674569502
# 訓練次數: 4300
# b: 176.34443096734984
# w: 17.67954004234197
# 損失函數: 12747.984481556634
# 損失函數: 6258.353873538104
# 訓練次數: 15700
# b: 239.7795931962225
# w: 14.096308721086581
# 損失函數: 6257.939595868352
# 訓練次數: 15800
# b: 239.84197429279143
# w: 14.09278503026234
# 損失函數: 6257.549592858561
# 訓練次數: 15900
# b: 239.90250018801436
# w: 14.089366133299057
# 損失函數: 6257.182442131533
# 訓練次數: 16000
# b: 239.9612260552083
# w: 14.086048913648257
# 損失函數: 6256.836804654449
# 訓練次數: 16100
# b: 240.01820542684757
# w: 14.082830347446965
# 損失函數: 6256.511419855324
# 訓練次數: 16200
# b: 240.07349024336054
# w: 14.079707500761332
# 損失函數: 6256.205101025564
# 訓練次數: 16300
# b: 240.12713090047814
# w: 14.07667752691208
# 損失函數: 6255.916730991928
# 訓練次數: 16400
# b: 240.17917629517223
# w: 14.073737663879617
# 損失函數: 6255.645258042115
# 訓練次數: 16500
# b: 240.22967387022865
# w: 14.070885231786248
# 損失函數: 6255.389692089067
# 訓練次數: 16600
# b: 240.27866965749394
# w: 14.068117630453331
# 損失函數: 6255.149101059995
# 訓練次數: 16700
# b: 240.3262083198369
# w: 14.065432337030996
# 損失函數: 6254.922607497052
# 訓練次數: 16800
# b: 240.3723331918617
# w: 14.062826903698426
# 損失函數: 6254.709385357201
# 訓練次數: 16900
# b: 240.41708631940972
# w: 14.060298955432515
# 損失函數: 6254.508656999459
# 訓練次數: 17000
# b: 240.46050849788756
# w: 14.057846187842868
# 損失函數: 6254.319690348874
# 訓練次數: 17100
# b: 240.50263930945474
# w: 14.05546636507119
# 損失函數: 6254.141796226505
# 訓練次數: 17200
# b: 240.5435171591051
# w: 14.05315731775317
# 損失函數: 6253.9743258359695
# 訓練次數: 17300
# b: 240.58317930967561
# w: 14.050916941040963
# 損失函數: 6253.816668397175
# 訓練次數: 17400
# b: 240.62166191581397
# w: 14.048743192684476
# 損失函數: 6253.668248918822
# 訓練次數: 17500
# b: 240.65900005693584
# w: 14.046634091169725
# 損失函數: 6253.528526101256
# 訓練次數: 17600
# b: 240.6952277692024
# w: 14.044587713912541
# 損失函數: 6253.396990362392
# 訓練次數: 17700
# b: 240.73037807654552
# w: 14.04260219550606
# 損失函數: 6253.273161979169
# 訓練次數: 17800
# b: 240.76448302077245
# w: 14.040675726020213
# 損失函數: 6253.156589337976
# 訓練次數: 17900
# b: 240.7975736907734
# w: 14.038806549351904
# 損失函數: 6253.04684728755
# 訓練次數: 18000
# b: 240.82968025086114
# w: 14.036992961624184
# 損失函數: 6252.943535588438
# 訓練次數: 18100
# b: 240.8608319682679
# w: 14.03523330963307
# 損失函數: 6252.846277453277
# 訓練次數: 18200
# b: 240.8910572398242
# w: 14.033525989340527
# 損失函數: 6252.754718172612
# 訓練次數: 18300
# b: 240.92038361784424
# w: 14.031869444412317
# 損失函數: 6252.668523821234
# 訓練次數: 18400
# b: 240.94883783524253
# w: 14.03026216479923
# 損失函數: 6252.587380040344
# 訓練次數: 18500
# b: 240.9764458299015
# w: 14.028702685360647
# 損失函數: 6252.510990891031
# 訓練次數: 18600
# b: 241.00323276831637
# w: 14.027189584528928
# 損失函數: 6252.439077774968
# 訓練次數: 18700
# b: 241.0292230685356
# w: 14.025721483013585
# 損失函數: 6252.371378418336
# 訓練次數: 18800
# b: 241.05444042242004
# w: 14.024297042543928
# 損失函數: 6252.307645915303
# 訓練次數: 18900
# b: 241.0789078172393
# w: 14.022914964649187
# 損失函數: 6252.247647827504
# 訓練次數: 19000
# b: 241.10264755662604
# w: 14.021573989474849
# 損失函數: 6252.191165336325
# 訓練次數: 19100
# b: 241.12568128090726
# w: 14.020272894634234
# 損失函數: 6252.137992444902
# 訓練次數: 19200
# b: 241.14802998683126
# w: 14.019010494094177
# 損失函數: 6252.087935226725
# 訓練次數: 19300
# b: 241.16971404670733
# w: 14.017785637093896
# 損失函數: 6252.040811118492
# 訓練次數: 19400
# b: 241.1907532269758
# w: 14.01659720709604
# 損失函數: 6251.9964482542
# 訓練次數: 19500
# b: 241.21116670622735
# w: 14.01544412076884
# 損失函數: 6251.954684838353
# 訓練次數: 19600
# b: 241.23097309268522
# w: 14.014325326998588
# 損失函數: 6251.9153685559
# 訓練次數: 19700
# b: 241.25019044116803
# w: 14.013239805931473
# 損失函數: 6251.878356016707
# 訓練次數: 19800
# b: 241.2688362695471
# w: 14.012186568043981
# 損失函數: 6251.843512232592
# 訓練次數: 19900
# b: 241.2869275747162
# w: 14.011164653240794
# 損失函數: 6251.810710125053
# 訓練次數: 20000
# b: 241.30448084808484
# w: 14.01017312997964
# 損失函數: 6251.779830061744

# %% [markdown]
# ### (8)畫圖檢查模型訓練結果

# %% [markdown]
# ###def F(x)=b+w*x ,偏值b，權重w(斜率)

# %%
plt.figure(figsize=(9,6))
plt.title("訓練模型和數據關係圖",
          fontproperties=twfont1,fontsize=20) 
plt.xlabel("x資料",fontproperties=twfont1,fontsize=20) 
plt.ylabel("y資料",fontproperties=twfont1,fontsize=20)
x=np.linspace(0,30, 2000)
plt.plot(x, F(x),label="模型函數")
plt.plot(train_x, train_y, 'go',label="訓練資料集")
plt.plot(valid_x, valid_y, 'ro',label="驗證資料集")
plt.legend(prop=twfont1)
plt.grid('k-', alpha=0.8)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title("Loss隨訓練次數的變化",fontproperties=twfont1,fontsize=20) 
plt.xlabel("訓練次數(x100)",fontproperties=twfont1,fontsize=20) 
plt.ylabel("Loss值",fontproperties=twfont1,fontsize=20)
plt.plot(Step_Loss,":o")
plt.show()

# %% [markdown]
# ### (9)觀察Loss值隨訓練次數的變化

# %%
plt.figure(figsize=(18,12))
plt.title("Loss隨訓練次數的變化",fontproperties=twfont1,fontsize=20) 
plt.xlabel("訓練次數(x100)",fontproperties=twfont1,fontsize=20) 
plt.ylabel("Loss值",fontproperties=twfont1,fontsize=20)
plt.plot(Step_Loss,"r:o",lw=1, ms=1)
plt.grid('k-', alpha=0.8)
plt.show()

# %% [markdown]
# ### (10)比較訓練好的迴歸模型函數在訓練資料集和驗證資料集的每筆平均Loss值

# %%
print("訓練資料集對回歸模型的每筆平均Loss值",
      Loss(train_x, train_y)/np.size(train_x))
print("驗證資料集對回歸模型的每筆平均Loss值",
      Loss(valid_x, valid_y)/np.size(valid_x))
# Out:
# 訓練資料集對回歸模型的每筆平均Loss值 520.9816525051453
# 驗證資料集對回歸模型的每筆平均Loss值 382.4439175923246

# %%
#I stop Runall

# %% [markdown]
# ### (11)動畫顯示偏值b和權重w的移動路徑

# %%
for i in range(len(Step_b)):
    plt.figure(figsize=(6,6))
    plt.title("動畫顯示迴歸係數的移動路徑",
              fontproperties=twfont1,fontsize=20)
    plt.xlabel("b",fontproperties=twfont1,fontsize=20) 
    plt.ylabel("w",fontproperties=twfont1,fontsize=20) 
    # X軸、Y軸刻度取array([Step_b,Step_w])的極值
    plt.xlim(np.min(np.array([Step_b,Step_w])),
             np.max(np.array([Step_b,Step_w])))
    plt.ylim(np.min(np.array([Step_b,Step_w])),
             np.max(np.array([Step_b,Step_w])))
    plt.scatter(Step_b[:i], Step_w[:i], s=20,color='r')
    plt.grid('k-', alpha=0.8)
    plt.pause(0.1)
    display.clear_output(wait=True)

# %%
for i in range(len(Step_b)):
    plt.figure(figsize=(10,10))
    plt.title("動畫顯示迴歸係數的移動路徑",
              fontproperties=twfont1,fontsize=20)
    plt.xlabel("b",fontproperties=twfont1,fontsize=20) 
    plt.ylabel("w",fontproperties=twfont1,fontsize=20) 
    # X軸、Y軸刻度取array([Step_b,Step_w])的極值
    plt.xlim(np.min(np.array(Step_b)),
             np.max(np.array(Step_b)))
    plt.ylim(np.min(np.array(Step_w)),
             np.max(np.array(Step_w)))
    plt.scatter(Step_b[:i], Step_w[:i], s=10,color='r')
    plt.grid('k-', alpha=0.8)
    plt.pause(0.1)
    display.clear_output(wait=True)

# %% [markdown]
# ### (12)顯示迴歸係數在損失函數等高線分布圖的移動路徑

# %%
#取b和w的網格範圍
b=np.linspace(0,300,200)
w=np.linspace(-30,70,200)
#計算每一個網格點對應的損失函數值
L=np.zeros((200,200)) 
for i in range(200):
  for j in range(200):
    L[j][i]=0.5*np.sum((train_y-(b[i]+w[j]*train_x))**2)
#鋪設網格
b,w=np.meshgrid(b,w)
# 開啟繪圖區域
plt.figure(figsize=(14,14))
CS=plt.contour(b,w,L,100)
plt.clabel(CS,inline=1,fontsize=10)
plt.scatter(Step_b[0:], Step_w[0:], s=20,color='r')
plt.title('等高線圖',fontproperties=twfont1)
plt.show()

# %%
#取b和w的網格範圍
b=np.linspace(0,300,50)
w=np.linspace(-30,70,50)
#計算每一個網格點對應的損失函數值
L=np.zeros((50,50)) 
for i in range(50):
  for j in range(50):
    L[j][i]=0.5*np.sum((train_y-(b[i]+w[j]*train_x))**2)
#鋪設網格
b,w=np.meshgrid(b,w)
# 開啟繪圖區域
plt.figure(figsize=(14,14))
CS=plt.contour(b,w,L,100)
plt.clabel(CS,inline=1,fontsize=10)
plt.scatter(Step_b[0:], Step_w[0:], s=20,color='r')
plt.title('等高線圖',fontproperties=twfont1)
plt.show()
